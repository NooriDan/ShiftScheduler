# %% [markdown]
# # Setup

# %%
from hello_world.domain      import Timetable, ShiftAssignment, Shift, TA, ConstraintParameters
from hello_world.utils       import print_ta_availability, initialize_logger, id_generator
from hello_world.solver      import TimetableSolverWithSolverManager

from typing import List, Tuple, Dict

import datetime as  dt

# %%
# Constants
AFTERNOON_START_TIME = dt.time(14, 30)
AFTERNOON_END_TIME   = dt.time(17, 30)

EVENING_START_TIME =  dt.time(18, 30)
EVENING_END_TIME   =  dt.time(21, 30)

NUM_OF_WEEKS = 1

DEFAULT_MIN_SHIFTS_PER_WEEK = 0
DEFAULT_MAX_SHIFTS_PER_WEEK = 2

DEFAULT_REQUIRED_SHIFTS_PER_SEMESTER = DEFAULT_MAX_SHIFTS_PER_WEEK * NUM_OF_WEEKS

# Logger Initialization
logger = initialize_logger()
logger.info("Starting test for 2DX3 timetable in 2026")
# Out:
# ...
# Logger initialized
# 	@ 2026-01-11 17:25:22
# 	Constraint version: default
# 	Data:               default
# ...
# Starting test for 2DX3 timetable in 2026

# %% [markdown]
# # Shifts

# %% [markdown]
# ## Enter Data

# %%
# Shift Data (<Series>, <Start Time>, <End Time>, <Required TAs>)
# ----------------------------------------------------------------------
# Monday Shifts
SHIFT_L01 = ("L01", AFTERNOON_START_TIME, AFTERNOON_END_TIME, 3)
SHIFT_L07 = ("L07", AFTERNOON_START_TIME, AFTERNOON_END_TIME, 2)

# Tuesday Shifts
SHIFT_L02 = ("L02", AFTERNOON_START_TIME, AFTERNOON_END_TIME, 3)
SHIFT_L08 = ("L08", AFTERNOON_START_TIME, AFTERNOON_END_TIME, 3)


# Wednesday Shifts
SHIFT_L03 = ("L03", AFTERNOON_START_TIME, AFTERNOON_END_TIME, 3)
SHIFT_L09 = ("L09", AFTERNOON_START_TIME, AFTERNOON_END_TIME, 2)

SHIFT_L06 = ("L06", EVENING_START_TIME, EVENING_END_TIME, 3)

# Thursday Shifts
SHIFT_L04 = ("L04", AFTERNOON_START_TIME, AFTERNOON_END_TIME, 3)
SHIFT_L10 = ("L10", AFTERNOON_START_TIME, AFTERNOON_END_TIME, 2)

# Friday Shifts
SHIFT_L05 = ("L05", AFTERNOON_START_TIME, AFTERNOON_END_TIME, 3)

# Create Shifts
shift_details_list = [ SHIFT_L01, SHIFT_L02, SHIFT_L03, SHIFT_L04, SHIFT_L05,
           SHIFT_L06, SHIFT_L07, SHIFT_L08, SHIFT_L09, SHIFT_L10 ]

# %% [markdown]
# ## Generate Objects

# %%
def generate_shift(shifts: List[Tuple[str, dt.time, dt.time, int]], num_weeks: int) -> Dict[str, List[Shift]]:
    shift_list = {}
    ids = id_generator()
    for item in shifts:
        series, start_time, end_time, required_tas = item
        temp = []
        for i in range(num_weeks):
            shift = Shift(
                id=next(ids),
                series=series,
                day_of_week="NA",
                week_id=i,
                start_time=start_time,
                end_time=end_time,
                required_tas=required_tas
            )
            temp.append(shift)
        shift_list[series] = temp
    return shift_list

def convert_dict_to_list(shift_dict: Dict[str, List[Shift]]) -> List[Shift]:
    shift_list = []
    for key in shift_dict:
        shift_list.extend(shift_dict[key])
    return shift_list

# %%
logger.info("Generating shifts for 2DX3 course; details:")
logger.info(f"Shift Details List: {[name for name, _, _, _ in shift_details_list]}")

shifts_dict = generate_shift(shifts=shift_details_list, num_weeks=NUM_OF_WEEKS)
shifts = convert_dict_to_list(shifts_dict)

logger.info(f"Generated {len(shifts)} shifts")
# Out:
# Generating shifts for 2DX3 course; details:
# Shift Details List: ['L01', 'L02', 'L03', 'L04', 'L05', 'L06', 'L07', 'L08', 'L09', 'L10']
# Generated 10 shifts

# %% [markdown]
# # TAs

# %% [markdown]
# ## Enter Data

# %%
ta_data = {
    "TA-1" : {
        "unavailable_shifts": shifts_dict["L01"] + shifts_dict["L02"],
        "max_shifts_per_week": 3
    },
    "TA-2" : {
        "unavailable_shifts": shifts_dict["L03"] + shifts_dict["L04"],
        "max_shifts_per_week": 3
    },
    "TA-3" : {
        "unavailable_shifts": shifts_dict["L05"] + shifts_dict["L06"],
        "max_shifts_per_week": 2
    },
    "TA-3" : {
        "unavailable_shifts": shifts_dict["L05"] + shifts_dict["L06"],
        "max_shifts_per_week": 2
    },
    "TA-3" : {
        "unavailable_shifts": shifts_dict["L05"] + shifts_dict["L06"],
        "max_shifts_per_week": 2
    },
    "TA-4" : {
        "unavailable_shifts": shifts_dict["L05"] + shifts_dict["L06"],
        "max_shifts_per_week": 2
    },
}

# %% [markdown]
# ## Generate Objects

# %%
def create_ta_objects(ta_data: Dict[str, Dict]) -> List[TA]:
    ta_objects = []
    id_gen = id_generator()
    for ta_name, details in ta_data.items():
        ta = TA(
            id=next(id_gen),
            name=ta_name,
            desired=details.get("desired_shifts", []),
            undesired=details.get("undesired_shifts", []),
            unavailable=details.get("unavailable_shifts", []),
            skill_level=details.get("skill_level", 1),
            required_shifts_per_semester=details.get("required_shifts_per_semester", DEFAULT_REQUIRED_SHIFTS_PER_SEMESTER),
            min_shifts_per_week=details.get("min_shifts_per_week", DEFAULT_MIN_SHIFTS_PER_WEEK),
            max_shifts_per_week=details.get("max_shifts_per_week", DEFAULT_MAX_SHIFTS_PER_WEEK),
        )
        ta_objects.append(ta)
    return ta_objects

ta_list = create_ta_objects(ta_data=ta_data)
logger.info("Created TA objects with the following details:")
logger.info(f"\t{len(ta_list)} TA objects")
logger.info(f"\tTA Names: {[ta.name for ta in ta_list]}")
# Out:
# Created TA objects with the following details:
# 	4 TA objects
# 	TA Names: ['TA-1', 'TA-2', 'TA-3', 'TA-4']

# %% [markdown]
# # Create the problem

# %%
def generate_shift_assignments(shifts: List[Shift]) -> List[ShiftAssignment]:
    shift_assignments = []
    id_gen = id_generator()
    for shift in shifts:
        for i in range(shift.required_tas):
            shift_assignment = ShiftAssignment(
                id=next(id_gen),
                shift=shift,
                assigned_ta=None
            )
            shift_assignments.append(shift_assignment)
    return shift_assignments


shift_assignments_unsolved = generate_shift_assignments(shifts=shifts)
len(shift_assignments_unsolved), len(shifts)
# Out:
# (27, 10)

# %%
id_gen = id_generator()
problem = Timetable(
    id=next(id_gen),
    shifts=shifts,
    tas=ta_list,
    constraint_parameters=ConstraintParameters(),
    shift_assignments=shift_assignments_unsolved
)
problem
# Out:
# Timetable(id='0', shifts=[Shift(id='0', series='L01', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='1', series='L02', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='2', series='L03', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='3', series='L04', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='4', series='L05', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='5', series='L06', day_of_week='NA', week_id=0, start_time=datetime.time(18, 30), end_time=datetime.time(21, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='6', series='L07', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=2, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='7', series='L08', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='8', series='L09', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=2, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='9', series='L10', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=2, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1))], tas=[TA(id='0', name='TA-1', required_shifts_per_semester=2, skill_level=1, desired=[], undesired=[], unavailable=[Shift(id='0', series='L01', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='1', series='L02', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1))], is_grad_student=True, min_shifts_per_week=0, max_shifts_per_week=3), TA(id='1', name='TA-2', required_shifts_per_semester=2, skill_level=1, desired=[], undesired=[], unavailable=[Shift(id='2', series='L03', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='3', series='L04', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1))], is_grad_student=True, min_shifts_per_week=0, max_shifts_per_week=3), TA(id='2', name='TA-3', required_shifts_per_semester=2, skill_level=1, desired=[], undesired=[], unavailable=[Shift(id='4', series='L05', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shift(id='5', series='L06', day_of_week='NA', week_id=0, start_time=datetime.time(18, 30), end_time=datetime.time(21, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1))], is_grad_student=True, min_shifts_per_week=0, max_shifts_per_week=2), TA(id='3', name='TA-4', required_shifts_per_semester=2, skill_level=1, desired=[], undesired=[], unavailable=[Shift(id='4', series='L05', day_of_week='NA', week_id=0, start_time=datetime.time(14, 30), end_time=datetime.time(17, 30), required_tas=3, alias='DEFAULT', shift_date=datetime.date(1900, 1, 1)), Shi ...

# %% [markdown]
# # Solve the problem

# %%
solver = TimetableSolverWithSolverManager(constraint_version="tabriz", logger=logger)
# solver = TimetableSolverBlocking(constraint_version="tabriz", logger=logger)

solution = solver.solve_problem(problem=problem)
# Out:
# 🚀 === Starting to Solve the Problem ===
# 	Running a sanity check on the problem...
# Performing sanity check on the problem instance...
# 	(1) Domain-specific sanity checks...
# 	Problem has 4 TAs and 10 shifts.
# 	⚠️  SANITY CHECK WARNING [TMTBL.workforce.count]: Total required TAs (27) over the planning problem exceeds anticipated TA duties (10).
# 		Count_TAs: 4, Num_of_weeks: 1, Total_available_TAs_per_week: 10
# 		Consider increasing the number of TAs or their maximum shifts per week, or reducing the required TAs per shift.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L01' in week '0' as desired.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L02' in week '0' as desired.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L03' in week '0' as desired.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L04' in week '0' as desired.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.unavailable]: Only 2 TAs are available for shift series 'L05' in week '0', but 3 are required.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L05' in week '0' as desired.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.unavailable]: Only 2 TAs are available for shift series 'L06' in week '0', but 3 are required.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L06' in week '0' as desired.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L07' in week '0' as desired.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L08' in week '0' as desired.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L09' in week '0' as desired.
# 	⚠️  SANITY CHECK WARNING [TMTBL.shifts.desired]: No TAs have shift series 'L10' in week '0' as desired.
# 	(1) ❌ Domain-specific sanity checks completed.
# 	(2) Checking number of shift assignments...
# 	(2) ❌ Number of shift assignments check completed.
# calling create_solver() method
# 	⚙️  Creating SolverConfig and SolverFactory...
# ✅ === SolverConfig and SolverFactory Created Successfully ===
# === Creating the SolverManager ===
# Requesting the SolverManager to create a SolverJob...
# 	✅ SolverJob created 7bbcccb7-60be-4975-8794-75a26fd1f1b4 id
#
#
# ==========================================
# 🛑 Starting blocking: waiting for solver job to finish
# -------------------------------------------
# Job ID: 7bbcccb7-60be-4975-8794-75a26fd1f1b4
# Solving started: time spent (25), best score (-27init/-4hard/0medium/0soft), environment mode (REPRODUCIBLE), move thread count (NONE), random (JDK with seed 0).
# Problem scale: entity count (27), variable count (27), approximate value count (4), approximate problem scale (1.80144 × 10^16).
# Construction Heuristic phase (0) ended: time spent (69), best score (-22hard/-17medium/15soft), move evaluation speed (2918/sec), step total (27).
#
# 💡 New best solution found! 2026-01-11 17:25:25 🧠
# 	📈 Updated score: -22hard/-17medium/15soft
#
#
# 💡 New best solution found! 2026-01-11 17:25:25 🧠
# 	📈 Updated score: -21hard/-17medium/13soft
#
#
# 💡 New best solution found! 2026-01-11 17:25:25 🧠
# 	📈 Updated score: -20hard/-17medium/6soft
#
#
# 💡 New best solution found! 2026-01-11 17:25:26 🧠
# 	📈 Updated score: -20hard/-17medium/8soft
#
#
# 💡 New best solution found! 2026-01-11 17:25:26 🧠
# 	📈 Updated score: -20hard/-17medium/9soft
#
#
# 💡 New best solution found! 2026-01-11 17:25:27 🧠
# 	📈 Updated score: -20hard/-17medium/10soft
#
#
# 💡 New best solution found! 2026-01-11 17:25:27 🧠
# 	📈 Updated score: -20hard/-17medium/11soft
#
# ⏱️ 2026-01-11 17:25:30 - Elapsed time: 5.2 seconds
# 	⏳ Job status: SOLVING_ACTIVE | Best score: -20hard/-17medium/11soft
#
#
# 💡 New best solution found! 2026-01-11 17:25:31 🧠
# 	📈 Updated score: -20hard/-17medium/12soft
#
# ⏱️ 2026-01-11 17:25:35 - Elapsed time: 10.3 seconds
# 	⏳ Job status: SOLVING_ACTIVE | Best score: -20hard/-17medium/12soft
#
# Local Search phase (1) ended: time spent (13914), best score (-20hard/-17medium/12soft), move evaluation speed (32225/sec), step total (88739).
# Solving ended: time spent (13936), best score (-20hard/-17medium/12soft), move evaluation speed (32015/sec), phase total (2), environment mode (REPRODUCIBLE), move thread count (NONE).
# ⏱️ 2026-01-11 17:25:41 - job has finished... Elapsed time: 15.7 seconds
#
# ✅ Blocking finished. Final job status: NOT_SOLVING - total time spent: 0:00:13.936000
# ==========================================
# Retrieving the final solution...
# Solver finished: status=NOT_SOLVING, score=-20hard/-17medium/12soft
# ✅ === Solver Finished Successfully ===
#
# 🗓️ === Final Timetable ===
# Score: -20hard/-17medium/12soft
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |                      |TA-1 (ID: 0)          |TA-2 (ID: 1)          |TA-3 (ID: 2)          |TA-4 (ID: 3)          |
# |                      |requires              |requires              |requires              |requires              |
# |                      |  budget: 2           |  budget: 2           |  budget: 2           |  budget: 2           |
# |                      |  minWk:  0           |  minWk:  0           |  minWk:  0           |  minWk:  0           |
# |                      |  maxWk:  3           |  maxWk:  3           |  maxWk:  2           |  maxWk:  2           |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# ***** Week 0 *****
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L01 NA 14:30 - week 0 |                      |TA-2                  |TA-3                  |TA-4                  |
# |requires 3 TAs        |                      |Neutral               |Neutral               |Neutral               |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L02 NA 14:30 - week 0 |                      |TA-2                  |TA-3                  |TA-4                  |
# |requires 3 TAs        |                      |Neutral               |Neutral               |Neutral               |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L03 NA 14:30 - week 0 |TA-1                  |                      |                      |                      |
# |requires 3 TAs        |Neutral               |                      |                      |                      |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L04 NA 14:30 - week 0 |TA-1                  |                      |                      |                      |
# |requires 3 TAs        |Neutral               |                      |                      |                      |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L05 NA 14:30 - week 0 |TA-1                  |TA-2                  |                      |                      |
# |requires 3 TAs        |Neutral               |Neutral               |                      |                      |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L06 NA 18:30 - week 0 |TA-1                  |                      |                      |                      |
# |requires 3 TAs        |Neutral               |                      |                      |                      |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L07 NA 14:30 - week 0 |TA-1                  |                      |                      |                      |
# |requires 2 TAs        |Neutral               |                      |                      |                      |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L08 NA 14:30 - week 0 |TA-1                  |                      |                      |                      |
# |requires 3 TAs        |Neutral               |                      |                      |                      |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L09 NA 14:30 - week 0 |TA-1                  |                      |                      |                      |
# |requires 2 TAs        |Neutral               |                      |                      |                      |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# |L10 NA 14:30 - week 0 |TA-1                  |                      |                      |                      |
# |requires 2 TAs        |Neutral               |                      |                      |                      |
# +----------------------+----------------------+----------------------+----------------------+----------------------+
# 🗓️ === /End of Final Timetable ===
